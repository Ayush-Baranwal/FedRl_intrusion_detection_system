# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('darkgrid') # darkgrid, white grid, dark, white and ticks
plt.rc('axes', titlesize=18)     # fontsize of the axes title
plt.rc('axes', labelsize=14)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=13)    # fontsize of the tick labels
plt.rc('ytick', labelsize=13)    # fontsize of the tick labels
plt.rc('legend', fontsize=13)    # legend fontsize
plt.rc('font', size=13)          # controls default text sizes

# %%
df1 = pd.read_csv('rl1.csv')
df2 = pd.read_csv('fed1.csv')
df3 = pd.read_csv('fed2.csv')
df4 = pd.read_csv('fed3.csv')
df1 = df1.iloc[1: , :]
df2 = df2.iloc[11: , :]
df3 = df3.iloc[11: , :]
df4 = df4.iloc[1: , :]
print(len(df1))
print(len(df2))
print(len(df3))
print(len(df4))
# print(df1.head(2))
# print(df1.iloc[:, 0])
# print(df1.head(1))
df1 = df1[['avg_attacker_episode_rewards','avg_defender_episode_rewards','hack_probability','cumulative_hack_probability','avg_episode_steps']]
df2 = df2[['avg_attacker_episode_rewards','avg_defender_episode_rewards','hack_probability','cumulative_hack_probability','avg_episode_steps']]
df3 = df3[['avg_attacker_episode_rewards','avg_defender_episode_rewards','hack_probability','cumulative_hack_probability','avg_episode_steps']]
df4 = df4[['avg_attacker_episode_rewards','avg_defender_episode_rewards','hack_probability','cumulative_hack_probability','avg_episode_steps']]
# Out:
# 99
# 99
# 99
# 99

# %%
df1['index_column'] = list(range(0, 9900, 100))
df2['index_column'] = list(range(0, 9900, 100))
df3['index_column'] = list(range(0, 9900, 100))
df4['index_column'] = list(range(0, 9900, 100))

# %%
plt.figure(figsize=(10,6), tight_layout=True)
#plotting
plt.plot(df1['index_column'], df1['avg_attacker_episode_rewards'], 'o-', linewidth=2, color=sns.color_palette('bright')[0])
plt.plot(df2['index_column'], df2['avg_attacker_episode_rewards'], 'o-', linewidth=2, color=sns.color_palette('bright')[1])
plt.plot(df3['index_column'], df3['avg_attacker_episode_rewards'], 'o-', linewidth=2, color=sns.color_palette('bright')[2])
plt.plot(df4['index_column'], df4['avg_attacker_episode_rewards'], 'o-', linewidth=2, color=sns.color_palette('bright')[3])
#customization
# plt.xticks(df1['index_column'])
plt.xticks(np.arange(0, 10000+1, step=1000))

plt.xlabel('No of iterations')
plt.ylabel('avg_attacker_episode_rewards')
plt.title('avg_attacker_episode_rewards vs No of iterations')
plt.legend(title='Agent', title_fontsize = 13, labels=['RL agent','Federated agent-1','Federated agent-2','Federated agent-3',])
plt.show()

# %%
plt.figure(figsize=(10,6), tight_layout=True)
#plotting
plt.plot(df1['index_column'], df1['avg_defender_episode_rewards'], 'o-', linewidth=2, color=sns.color_palette('bright')[0])
plt.plot(df2['index_column'], df2['avg_defender_episode_rewards'], 'o-', linewidth=2, color=sns.color_palette('bright')[1])
plt.plot(df3['index_column'], df3['avg_defender_episode_rewards'], 'o-', linewidth=2, color=sns.color_palette('bright')[2])
plt.plot(df4['index_column'], df4['avg_defender_episode_rewards'], 'o-', linewidth=2, color=sns.color_palette('bright')[3])
#customization
# plt.xticks(df1['index_column'])
plt.xticks(np.arange(0, 10000+1, step=1000))

plt.xlabel('No of iterations')
plt.ylabel('avg_defender_episode_rewards')
plt.title('avg_defender_episode_rewards vs No of iterations')
plt.legend(title='Agent', title_fontsize = 13, labels=['RL agent','Federated agent-1','Federated agent-2','Federated agent-3',])
plt.show()

# %%
plt.figure(figsize=(10,6), tight_layout=True)
#plotting
plt.plot(df1['index_column'], df1['avg_episode_steps'], 'o-', linewidth=2, color=sns.color_palette('bright')[0])
plt.plot(df2['index_column'], df2['avg_episode_steps'], 'o-', linewidth=2, color=sns.color_palette('bright')[1])
plt.plot(df3['index_column'], df3['avg_episode_steps'], 'o-', linewidth=2, color=sns.color_palette('bright')[2])
plt.plot(df4['index_column'], df4['avg_episode_steps'], 'o-', linewidth=2, color=sns.color_palette('bright')[3])

#customization
# plt.xticks(df1['index_column'])
plt.xticks(np.arange(0, 10000+1, step=1000))

plt.xlabel('No of iterations')
plt.ylabel('avg_episode_steps')
plt.title('avg_episode_steps vs No of iterations')
plt.legend(title='Agent', title_fontsize = 13, labels=['RL agent','Federated agent-1','Federated agent-2','Federated agent-3',])
plt.show()

# %%
plt.figure(figsize=(10,6), tight_layout=True)
#plotting
plt.plot(df1['index_column'], df1['hack_probability'], 'o-', linewidth=2, color=sns.color_palette('bright')[0])
plt.plot(df2['index_column'], df2['hack_probability'], 'o-', linewidth=2, color=sns.color_palette('bright')[1])
plt.plot(df3['index_column'], df3['hack_probability'], 'o-', linewidth=2, color=sns.color_palette('bright')[2])
plt.plot(df4['index_column'], df4['hack_probability'], 'o-', linewidth=2, color=sns.color_palette('bright')[3])
#customization
# plt.xticks(df1['index_column'])
plt.xticks(np.arange(0, 10000+1, step=1000))

plt.xlabel('No of iterations')
plt.ylabel('hack_probability')
plt.title('hack_probability vs No of iterations')
plt.legend(title='Agent', title_fontsize = 13, labels=['RL agent','Federated agent-1','Federated agent-2','Federated agent-3',])
plt.show()

# %%
plt.figure(figsize=(10,6), tight_layout=True)
#plotting
plt.plot(df1['index_column'], df1['cumulative_hack_probability'], 'o-', linewidth=2, color=sns.color_palette('bright')[0])
plt.plot(df2['index_column'], df2['cumulative_hack_probability'], 'o-', linewidth=2, color=sns.color_palette('bright')[1])
plt.plot(df3['index_column'], df3['cumulative_hack_probability'], 'o-', linewidth=2, color=sns.color_palette('bright')[2])
plt.plot(df4['index_column'], df4['cumulative_hack_probability'], 'o-', linewidth=2, color=sns.color_palette('bright')[3])
#customization
# plt.xticks(df1['index_column'])
plt.xticks(np.arange(0, 10000+1, step=1000))

plt.xlabel('No of iterations')
plt.ylabel('cumulative_hack_probability')
plt.title('cumulative_hack_probability vs No of iterations')
plt.legend(title='Agent', title_fontsize = 13, labels=['RL agent','Federated agent-1','Federated agent-2','Federated agent-3',])
plt.show()

# %%
plt.plot(df1['index_column'], df1['avg_attacker_episode_rewards'], label = "sinle 1")
plt.plot(df2['index_column'], df2['avg_attacker_episode_rewards'], label = "fed 1")
plt.plot(df3['index_column'], df3['avg_attacker_episode_rewards'], label = "fed 2")
plt.plot(df4['index_column'], df4['avg_attacker_episode_rewards'], label = "fed 3")
plt.rcParams["figure.figsize"] = (10,5)
plt.legend()
plt.show()

# %%
plt.plot(df1['index_column'], df1['avg_defender_episode_rewards'], label = "single 1")
plt.plot(df2['index_column'], df2['avg_defender_episode_rewards'], label = "fed 1")
plt.plot(df3['index_column'], df3['avg_defender_episode_rewards'], label = "fed 2")
plt.plot(df4['index_column'], df4['avg_defender_episode_rewards'], label = "fed 3")
# plt.rcParams["figure.figsize"] = (10,5)
plt.legend()
plt.show()

# %%
plt.plot(df1['index_column'], df1['avg_episode_steps'], label = "single 1")
plt.plot(df2['index_column'], df2['avg_episode_steps'], label = "fed 1")
plt.plot(df3['index_column'], df3['avg_episode_steps'], label = "fed 2")
plt.plot(df4['index_column'], df4['avg_episode_steps'], label = "fed 3")
# plt.rcParams["figure.figsize"] = (10,5)
plt.legend()
plt.show()

# %%
plt.plot(df1['index_column'], df1['hack_probability'], label = "single 1")
plt.plot(df2['index_column'], df2['hack_probability'], label = "fed 1")
plt.plot(df3['index_column'], df3['hack_probability'], label = "fed 2")
plt.plot(df4['index_column'], df4['hack_probability'], label = "fed 3")
plt.rcParams["figure.figsize"] = (10,5)
plt.legend()
plt.show()

# %%
plt.plot(df1['index_column'], df1['cumulative_hack_probability'], label = "single 1")
plt.plot(df2['index_column'], df2['cumulative_hack_probability'], label = "fed 1")
plt.plot(df3['index_column'], df3['cumulative_hack_probability'], label = "fed 2")
plt.plot(df4['index_column'], df4['cumulative_hack_probability'], label = "fed 3")
plt.rcParams["figure.figsize"] = (10,5)
plt.legend()
plt.show()

# %% [markdown]
# #seprate graph

# %%
# df1.plot.line(figsize=(20, 20))
axes = df1.plot.line(subplots=True,figsize=(10, 10))

# %%
axes = df2.plot.line(subplots=True,figsize=(10, 10))

# %%
# axes = df3.plot.line(subplots=True,figsize=(10, 10))
